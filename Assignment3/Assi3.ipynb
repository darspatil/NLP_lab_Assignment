# %%
import pandas as pd
import re
import nltk

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
text = "An "intro" (introduction) is a, short, initial segment in media, writing, or presentations designed to provide context, grab attention, and set the tone. Effective intros—often used in videos, songs, or speeches—hook the audience immediately, establish credibility, and preview the content to follow. "
# Out:
#   File "/tmp/ipython-input-3435932570.py", line 1
#     text = "An "intro" (introduction) is a, short, initial segment in media, writing, or presentations designed to provide context, grab attention, and set the tone. Effective intros—often used in videos, songs, or speeches—hook the audience immediately, establish credibility, and preview the content to follow. "
#                 ^
# SyntaxError: invalid syntax

# %%
# Out:
# 'an introduction is a short initial segment in media writing or presentations designed to provide context grab attention and set the tone effective introsoften used in videos songs or speecheshook the audience immediately establish credibility and preview the content to follow '
