# %%
import pandas as pd
import re
import nltk

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
texts = [
    "I love INDIA",
    "This movie is interesting!!",
    "AI will change the future",
    "I don't like this movie"
]

labels = [
    "positive",
    "positive",
    "positive",
    "negative"
]

# %%
import pandas as pd

df = pd.DataFrame({
    "text": texts,
    "label": labels
})

df.to_csv("data.csv", index=False)
print("CSV file created successfully")
# Out:
# CSV file created successfully

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#                           text     label
# 0                 I love INDIA  positive
# 1  This movie is interesting!!  positive
# 2    AI will change the future  positive
# 3      I don't like this movie  negative

# %%
import re

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

df['cleaned_text'] = df['text'].apply(clean_text)

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
    return " ".join(word for word in text.split() if word not in stop_words)

df['no_stopwords'] = df['cleaned_text'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

def lemmatize_text(text):
    return " ".join(lemmatizer.lemmatize(word) for word in text.split())

df['lemmatized_text'] = df['no_stopwords'].apply(lemmatize_text)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['label_encoded'] = le.fit_transform(df['label'])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(max_features=1000)

X_tfidf = tfidf.fit_transform(df['lemmatized_text'])
X_tfidf = X_tfidf.toarray()
X_tfidf
# Out:
# array([[0.        , 0.        , 0.        , 0.        , 0.70710678,
#         0.        , 0.        , 0.70710678, 0.        ],
#        [0.        , 0.        , 0.        , 0.        , 0.        ,
#         0.78528828, 0.        , 0.        , 0.6191303 ],
#        [0.57735027, 0.57735027, 0.        , 0.57735027, 0.        ,
#         0.        , 0.        , 0.        , 0.        ],
#        [0.        , 0.        , 0.61761437, 0.        , 0.        ,
#         0.        , 0.61761437, 0.        , 0.48693426]])

# %%
tfidf_df = pd.DataFrame(
    X_tfidf,
    columns=tfidf.get_feature_names_out()
)

# %%
df.to_csv("processed_text.csv", index=False)
tfidf_df.to_csv("tfidf_features.csv", index=False)

# %%
tfidf_df.head()
# Out:
#         ai   change      dont   future     india  interesting      like  \
# 0  0.00000  0.00000  0.000000  0.00000  0.707107     0.000000  0.000000
# 1  0.00000  0.00000  0.000000  0.00000  0.000000     0.785288  0.000000
# 2  0.57735  0.57735  0.000000  0.57735  0.000000     0.000000  0.000000
# 3  0.00000  0.00000  0.617614  0.00000  0.000000     0.000000  0.617614
#
#        love     movie
# 0  0.707107  0.000000
# 1  0.000000  0.619130
# 2  0.000000  0.000000
# 3  0.000000  0.486934
